# %% [markdown]
# # Unit 15. elif를 사용하여 여러 방향으로 분기하기

# %% [markdown]
# ## 15.1 elif 사용하기

# %%
# if, else와 마찬가지로 조건식 끝에 :를 붙여야하고, elif 단독으로 사용할 수 없음
x = 20
if x == 10:
    print('10입니다.')
elif x == 20:
    print('20입니다.')
# Out:
# 20입니다.

# %%
# if, elif, else 모두 사용하기
# 단, elif 앞에 else가 오면 잘못된 문법이다.
x = 30
if x == 10:
    print('10입니다.')
elif x == 20:
    print('20입니다.')
else: # 앞의 조건식에 모두 만족하지 않을 때
    print('10도 20도 아닙니다.')
# Out:
# 10도 20도 아닙니다.

# %%
botton = int(input())

if botton == 1:
    print('콜라')
elif botton == 2:
    print('사이다')
elif botton == 3:
    print('환타')
else:
    print('제공하지 않는 메뉴')
# Out:
#  10
# 제공하지 않는 메뉴
