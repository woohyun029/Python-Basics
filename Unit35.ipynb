# %% [markdown]
# # Unit 35. 클래스 속성과 정적, 클래스 메서드 사용하기

# %% [markdown]
# ## 35.1 클래스 속성과 인스턴스 속성 알아보기

# %%
# 클래스 속성은 다음과 같이 클래스에 바로 속성을 만듦
# def 클래스이름:
#     속성 = 값

class Person:
    bag = []

    def put_bag(self, stuff):
        self.bag.append(stuff)

james = Person()
james.put_bag('책')

maria = Person()
maria.put_bag('열쇠')

print(james.bag)
print(maria.bag)
# Out:
# ['책', '열쇠']
# ['책', '열쇠']

# %%
class Person:
    def __init__(self):
        self.bag = []

    def put_bag(self, stuff):
        self.bag.append(stuff)

james = Person()
james.put_bag('책')

maria = Person()
maria.put_bag('열쇠')

print(james.bag)
print(maria.bag)
# Out:
# ['책']
# ['열쇠']

# %%
# 비공개 클래스 속성 사용하기
# 클래스 안에서만 접근할 수 있고, 클래스 바깥에서는 접근할 수 없음
# def 클래스 이름:
#     __속성 = 값 # 비공개 클래스 속성

class Knight:
    __item_limit = 10 # 비공개 클래스 속성

    def print_item_limit(self):
        print(Knight.__item_limit) # 클래스 안에서 접근할 수 있음

x = Knight()
x.print_item_limit() # 10

print(Knight.__item_limit) # 클래스 바깥에서는 접근할 수 없음
# Out:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 15
#      12 x = Knight()
#      13 x.print_item_limit() # 10
# ---> 15 print(Knight.__item_limit) # 클래스 바깥에서는 접근할 수 없음
#
# AttributeError: type object 'Knight' has no attribute '__item_limit'

# %% [markdown]
# ## 35.2 정적 메서드 사용하기

# %%
# 정적 메서드는 다음과 같이 메서드 위에 @staticmethod를 붙임
# 정적 메서드는 매개변수에 self를 지정하지 않음

# class 클래스이름:
#     @staticmethod
#     def 메서드(매개변수1, 매개변수2):
#         코드

class Calc:
    @staticmethod
    def add(a, b):
        print(a + b)

    @staticmethod
    def mul(a, b):
        print(a * b)

Calc.add(10, 20) # 클래스에서 바로 메서드 호출
Calc.mul(10, 20) # 클래스에서 바로 메서드 호출
# Out:
# 30
# 200

# %% [markdown]
# > 정적 메서드 사용하기
# - 정적 메서드는 self를 받지 않으므로 인스턴스 속 성에는 접근할 수 없음
# - 인스턴스 속성, 인스턴스메서드가 필요 없을 때 사용함
# - 메서드의 실행이 외부 상태에 영향을끼치지 않은 순수 함수(pure function)를 만들 때 사용함
# - 순수 함수는 부수 효과(side effect)가 없고 입력 값이같으면 언제나 같은 출력 값을 반환함
# - 인스턴스의 상태를 변화시키지 않는 메서드를 만들 때 사용함

# %% [markdown]
# ## 35.3 클래스 메서드 사용하기

# %%
# 클래스 메서드는 첫 번째 매개변수에 cls를 지정해야한다
# class 클래스이름:
#     @classmethod
#     def 메서드(cls, 매개변수1, 매개변수2):
#         코드

class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def print_count(cls):
        print(f'{cls.count}명 생성되었습니다.')

james = Person()
maria = Person()

Person.print_count() # 2명 생성되었습니다
# Out:
# 2명 생성되었습니다.
