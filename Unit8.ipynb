# %% [markdown]
# # Unit 8. 불과 비교, 논리 연산자 알아보기

# %% [markdown]
# ## 8.1 불과 비교 연산자 사용하기

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
3 > 1
# Out:
# True

# %%
3 < 1
# Out:
# False

# %%
10 == 10 # 10과 10이 같은지 비교
# Out:
# True

# %%
10 != 5 # 10과 5가 다른지 비교
# Out:
# True

# %%
'Python' == 'Python'
# Out:
# True

# %%
'Python' == 'python'
# Out:
# False

# %%
'Python' != 'python'
# Out:
# True

# %%
10 > 20
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
10 >= 10
# Out:
# True

# %%
10 <= 10
# Out:
# True

# %%
id(1)
# Out:
# 140727364920232

# %%
id(1.0)
# Out:
# 2933774434416

# %%
# is와 ==는 다르게 작동된다.
1 == 1.0
# Out:
# True

# %%
1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\User\AppData\Local\Temp\ipykernel_11900\3336455986.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   1 is 1.0
# False

# %%
a = -5
a is -5
# Out:
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\User\AppData\Local\Temp\ipykernel_11900\632354002.py:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   a is -5
# True

# %%
# 값을 비교할 때는 메모리 주소가 달라질 수 있기 때문에 is로 비교하지 않고 '==' 연산자로 비교한다.
a = -6
a is -6
# Out:
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\User\AppData\Local\Temp\ipykernel_11900\3817397500.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   a is -6
# False

# %%
a == -6
# Out:
# True

# %% [markdown]
# ## 8.2 논리 연산자 사용하기

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True and False or not False # True and Flase or True = False or True = True
# Out:
# True

# %%
10 == 10 and 10 != 5 # True and True, '비교 연산자'를 먼저 판단 후, '논리 연산자' 판단
# Out:
# True

# %%
10 > 5 or 10 < 3 # True or Flase
# Out:
# True

# %%
not 10 > 5 # not True
# Out:
# False

# %%
# bool : 정수0, 실수0.0 이외의 모든 숫자는 True
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('Flase')
# Out:
# True

# %%
bool(' ')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
print(False and True); print(False and False) # False, 첫 값만으로 결과가 확실할 때 두 번째 값은 판단하지 않는다.
# Out:
# False
# False

# %%
print(True or True); print(True or False) # 같은 맥락으로 두 번째 값은 판단하지 않고 바로 출력하는 과정이다.
# Out:
# True
# True

# %%
True and 'Python'
# Out:
# 'Python'

# %%
'Python' and True
# Out:
# True

# %%
'Python' and False
# Out:
# False

# %%
False and 'Python'
# Out:
# False

# %%
0 and 'Python' # 0은 False이므로 and 연산자는 두 번째 값을 평가하지 않음
# Out:
# 0

# %%
True or 'Python'
# Out:
# True

# %%
'Python' or True
# Out:
# 'Python'

# %%
False or 'Python'
# Out:
# 'Python'

# %%
0 or False
# Out:
# False
