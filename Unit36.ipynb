# %% [markdown]
# # Unit 36. 클래스 상속 사용하기

# %% [markdown]
# ## 36.1 사람 클래스로 학생 클래스 만들기

# %%
# 클래스 상속은 물려받은 기능을유지한 채로 다른 기능을 추가할 때 사용하는 기능임
# 기능을 물려주는 클래스 : 기반 클래스(base class)
# 상속을 받아 새롭게 만드는 클래스 : 파생 클래스(derived class)

# class 기반클래스이름:
#     코드
# class 파생클래스이름(파생클래스이름):
#     코드

class Person():
    def greeting(self):
        print('안녕하세요.')

class Student(Person):
    def study(self):
        print('공부하기')

james = Student()
james.greeting() # 안녕하세요.: 기반 클래스 Person의 메서드 호출
james.study() # 공부하기: 파생 클래스 Student에 추가한 study 메서드
# Out:
# 안녕하세요.
# 공부하기

# %% [markdown]
# ## 36.2 상속 관계와 포함 관계 알아보기

# %%
class Person:
    def greeting(self):
        print('안녕하세요.')
class PersonList():
    def __init__(self):
        self.person_list = [] # 리스트 속성에 Person 인스턴스를 넣어서 관리

    def append_person(self, person): # 리스트 속성에 Person 인스턴스를 추가하는 방식
        self.person_list.append(person)

# %% [markdown]
# ## 36.3 기반 클래스의 속성 사용하기

# %%
class Person:
    def __init__(self):
        print('Person __init__')
        self.hello = '안녕하세요.'

class Student(Person):
    def __init__(self):
        print('Student __init__')
        self.school = '파이썬 코딩 도장'

james = Student()
print(james.school)
print(james.hello) # 기반 클래스의 속성을 출력하려고 하면 에러가 발생한다
# Out:
# Student __init__
# 파이썬 코딩 도장
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 13
#      11 james = Student()
#      12 print(james.school)
# ---> 13 print(james.hello) # 기반 클래스의 속성을 출력하려고 하면 에러가 발생한다
#
# AttributeError: 'Student' object has no attribute 'hello'

# %%
class Person:
    def __init__(self):
        print('Person __init__')
        self.hello = '안녕하세요.'

class Student(Person):
    def __init__(self):
        print('Student __init__')
        super().__init__() # super()로 기반 클래스 초기화하기
        self.school = '파이썬 코딩 도장'

james = Student()
print(james.school)
print(james.hello) # 기반 클래스의 속성을 출력하려고 하면 에러가 발생한다
# Out:
# Student __init__
# Person __init__
# 파이썬 코딩 도장
# 안녕하세요.

# %% [markdown]
# ## 36.4 메서드 오버라이딩 사용하기

# %%
class Person:
    def greeting(self):
        print('안녕하세요.')
class Student(Person):
    def greeting(self):
        print('안녕하세요. 저는 파이썬 코딩 도장 학생입니다.')

james = Student()
james.greeting()
# Out:
# 안녕하세요. 저는 파이썬 코딩 도장 학생입니다.

# %%
class Person:
    def greeting(self):
        print('안녕하세요.')
class Student(Person):
    def greeting(self):
        super().greeting() # 기반 클래스의 메서드 호출하여 중복을 줄임
        print('안녕하세요. 저는 파이썬 코딩 도장 학생입니다.')

james = Student()
james.greeting()
# Out:
# 안녕하세요.
# 안녕하세요. 저는 파이썬 코딩 도장 학생입니다.

# %% [markdown]
# ## 36.5 다중 상속 사용하기

# %%
# 다중 상속은 여러 기반 클래스로부터 상속을 받아서 파생 클래스를 만드는 방법이다
class Person:
    def greeting(self):
        print('안녕하세요.')
class University:
    def manage_credit(self):
        print('학점 관리')

class Undergraduate(Person, University):
    def study(self):
        print('공부하기')

james = Undergraduate()
james.greeting() # 안녕하세요 : 기반 클래스 Person의 메서드 호출
james.manage_credit() # 학점 관리 : 기반 클래스 University의 메서드 호출
james.study() # 공부하기 : 파생 클래스 Undergraduate에 추가한 study 메서드
# Out:
# 안녕하세요.
# 학점 관리
# 공부하기

# %%
# 다이아몬드 상속
class A:
    def greeting(self):
        print('안녕하세요. A입니다.')

class B:
    def greeting(self):
        print('안녕하세요. B입니다.')

class C:
    def greeting(self):
        print('안녕하세요. C입니다.')

class D(B, C):
    pass

x = D()
x.greeting() # 왼쪽에 있는 B부터 시행
# Out:
# 안녕하세요. B입니다.

# %%
# 메서드 탐색 순서 확인하기 : mro() 메서드
D.mro()
# Out:
# [__main__.D, __main__.B, __main__.C, object]

# %% [markdown]
# ## 36.6 추상 클래스 사용하기

# %%
# 추상 클래스 : 메서드의 목록만 가진 클래스이며 상속받는 클래스에서 메서드 구현을 강제하기 위해 사용한다

from abc import *

class StudentBase(metaclass=ABCMeta):
    @abstractmethod
    def study(self):
        pass

    @abstractmethod
    def go_to_school(self):
        pass

class Student(StudentBase):
    def study(self):
        print('공부하기')
    def go_to_school(self):
        print('학교가기')

james = Student()
james.study()
james.go_to_school()
# Out:
# 공부하기
# 학교가기
