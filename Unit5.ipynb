# %% [markdown]
# # Unit 5. 숫자 계산하기

# %% [markdown]
# ## 5.1 정수 계산하기

# %% [markdown]
# > 파이썬의 숫자 자료형<br>
# >- 정수(int), 실수(float), 복소수(complex)

# %%
1+1
# Out:
# 2

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
5/2 # 나눗셈을 실수로 출력
# Out:
# 2.5

# %%
5//2 # 나눗셈을 정수로 출력
# Out:
# 2

# %%
4/2
# Out:
# 2.0

# %%
4//2
# Out:
# 2

# %%
5%2 # 모듈로(modulo)연산자 : 나눗셈에서 '나머지' 구하기
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
2 ** 10
# Out:
# 1024

# %%
int(3.3)
# Out:
# 3

# %%
int(5/2)
# Out:
# 2

# %%
int('10')
# Out:
# 10

# %%
type(10) # 자료형 확인하기
# Out:
# int

# %%
divmod(5,2) # '5/2'의 몫과 나머지 구하기
# Out:
# (2, 1)

# %%
a,b = divmod(5,2)

# %%
print(a,b)
# Out:
# 2 1

# %%
0b110 # 110의 2진수 알아보기 (0b)
# Out:
# 6

# %%
0o10 # 10의 9진수 알아보기 (0o)
# Out:
# 8

# %%
0xf # f의 16진수 알아보기 (0x)
# Out:
# 15

# %% [markdown]
# ## 5.2 실수 계산하기

# %%
3.5+2.1
# Out:
# 5.6

# %%
4.3-2.7
# Out:
# 1.5999999999999996

# %%
5.5/3.1
# Out:
# 1.7741935483870968

# %%
4.2+5
# Out:
# 9.2

# %%
float(5) # 값을 '실수'로 만들기
# Out:
# 5.0

# %%
float(1+2)
# Out:
# 3.0

# %%
float('5.3')
# Out:
# 5.3

# %%
type(3.5)
# Out:
# float

# %%
1.2+1.3j # 복소수 계산하기, 허수부 숫자 뒤에 'j'를 붙임
# Out:
# (1.2+1.3j)

# %%
complex(1.2,1.3) # 두 실수를 복소수로 만들기
# Out:
# (1.2+1.3j)

# %% [markdown]
# ## 5.3 괄호 사용하기

# %%
35 + 2*1
# Out:
# 37

# %%
(35+1)*2
# Out:
# 72
