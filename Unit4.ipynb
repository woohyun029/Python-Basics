# %% [markdown]
# # Unit 4. 기본 문법 알아보기

# %% [markdown]
# ## 4.1 세미콜론

# %%
print('Hello, world!') # 파이썬은 세미콜론을 붙이지 않음
# Out:
# Hello, world!

# %%
print('Hello'); print('1234') # 보통 한 줄에 여러 구문을사용할 때 세미콜론으로 구분해줌
# Out:
# Hello
# 1234

# %% [markdown]
# ## 4.2 주석
# - '한 줄 주석'과 '블록 주석'

# %%
# Hello, world! 출력
print('Hello, world!')
# Out:
# Hello, world!

# %%
# print('Hello, wolrd!')
# print('123456789')

# %% [markdown]
# ## 4.3 들여쓰기
# - 파이썬은 들여쓰기 자체가 문법이다.

# %%
a = 10
if a == 10:
    print('10입니다.')
# Out:
# 10입니다.

# %% [markdown]
# ## 4.4 코드 블록
# - 들여쓰기를 기준으로 코드 블록을 구성, 코드 블록은 특정한 동작을 위해서 코드가 모여 있는 상태

# %%
a = 10
if a ==10:
    print('10')
    print('입니다.')
# Out:
# 10
# 입니다.
