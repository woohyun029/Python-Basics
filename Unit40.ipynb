# %% [markdown]
# # Unit 40. 제너레이터 사용하기

# %% [markdown]
# ## 40.1 제너레이터와 yield 알아보기

# %%
def number_generator():
    yield 0
    yield 1
    yield 2
for i in number_generator():
    print(i)
# Out:
# 0
# 1
# 2

# %%
g = number_generator()
g
# Out:
# <generator object number_generator at 0x0000022AE337F110>

# %%
dir(g)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__del__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'close',
#  'gi_code',
#  'gi_frame',
#  'gi_running',
#  'gi_suspended',
#  'gi_yieldfrom',
#  'send',
#  'throw']

# %%
g.__next__()
# Out:
# 0

# %%
g.__next__()
# Out:
# 1

# %%
g.__next__()
# Out:
# 2

# %%
g.__next__()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 g.__next__()
#
# StopIteration:

# %% [markdown]
# ## 40.2 제너레이터 만들기

# %%
def number_generator(stop):
    n = 0 # 숫자는 0부터 시작
    while n < stop: # 현재 숫자가 반복을 끝낼 숫자보다 작을 때 반복
        yield n # 현재숫자를 바깥으로 전달 
        n += 1 # 현재 숫자를 증가시킴

for i in number_generator(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
g = number_generator(3)
next(g)
# Out:
# 0

# %%
next(g)
# Out:
# 1

# %%
next(g)
# Out:
# 2

# %%
next(g)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 next(g)
#
# StopIteration:

# %%
def upper_generator(x):
    for i in x:
        yield i.upper() # 함수의 반환값을 바깥으로 전달

fruits = ['apple', 'pear', 'grape', 'pineapple', 'orange']
for i in upper_generator(fruits):
    print(i)
# Out:
# APPLE
# PEAR
# GRAPE
# PINEAPPLE
# ORANGE

# %% [markdown]
# ## 40.3 yield from으로 값을 여러 번 바깥으로 전달하기

# %%
def number_generator():
    x = [1, 2, 3]
    for i in x:
        yield i

for i in number_generator():
    print(i)
# Out:
# 1
# 2
# 3

# %%
def number_generator():
    x = [1, 2, 3]
    yield from x # 리스트에 들어있는 요소를 한 개씩 바깥으로 전달

for i in number_generator():
    print(i)
# Out:
# 1
# 2
# 3
